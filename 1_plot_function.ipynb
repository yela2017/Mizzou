# %%
import numpy as np

x = np.arange(-5,5,0.)

print(x)
# Out:
# [-5.  -4.5 -4.  -3.5 -3.  -2.5 -2.  -1.5 -1.  -0.5  0.   0.5  1.   1.5
#   2.   2.5  3.   3.5  4.   4.5]

# %%
def lime(x,m,b):
    y = m*x + b
    return y

y = line(x,1,0)
# Out:
# [-0.5  -0.25  0.    0.25  0.5   0.75  1.    1.25  1.5   1.75  2.    2.25
#   2.5   2.75  3.    3.25  3.5   3.75  4.    4.25]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure()

plt.plot(x,y)
plt.grid()
plt.show()

# %%
x = np.arange(-5,5,0.1)
y = x**2
print(y)
# Out:
# [2.50000000e+01 2.40100000e+01 2.30400000e+01 2.20900000e+01
#  2.11600000e+01 2.02500000e+01 1.93600000e+01 1.84900000e+01
#  1.76400000e+01 1.68100000e+01 1.60000000e+01 1.52100000e+01
#  1.44400000e+01 1.36900000e+01 1.29600000e+01 1.22500000e+01
#  1.15600000e+01 1.08900000e+01 1.02400000e+01 9.61000000e+00
#  9.00000000e+00 8.41000000e+00 7.84000000e+00 7.29000000e+00
#  6.76000000e+00 6.25000000e+00 5.76000000e+00 5.29000000e+00
#  4.84000000e+00 4.41000000e+00 4.00000000e+00 3.61000000e+00
#  3.24000000e+00 2.89000000e+00 2.56000000e+00 2.25000000e+00
#  1.96000000e+00 1.69000000e+00 1.44000000e+00 1.21000000e+00
#  1.00000000e+00 8.10000000e-01 6.40000000e-01 4.90000000e-01
#  3.60000000e-01 2.50000000e-01 1.60000000e-01 9.00000000e-02
#  4.00000000e-02 1.00000000e-02 3.15544362e-28 1.00000000e-02
#  4.00000000e-02 9.00000000e-02 1.60000000e-01 2.50000000e-01
#  3.60000000e-01 4.90000000e-01 6.40000000e-01 8.10000000e-01
# ...

# %%
# %matplotlib inline
plt.figure()
plt.plot(x,y)
plt.grid()
plt.show()

# %%
print(x)
print(y)

index = 10
d = 5
x[index]
P = [x[index],y[index]]
index2 = index+d
Q = [x[index2],y[index2]]
print(P)
print(Q)

def line2pts9(x,P0,P1):
    y = (x-P0[0])*(P1[1]-P0[1])/(P1[0]-P0[0])+P0[1]
    return y

tangent_y = line2pts9(x,P,Q)
plt.figure()
plt.plot(x,y,'b')
plt.plot((P[0],Q[0]),(P[1],Q[1]),'r.')
plt.plot(x,tangent_y,'g')
plt.grid()
plt.show()
# Out:
# [-2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75]
# [-0.90929743 -0.98398595 -0.99749499 -0.94898462 -0.84147098 -0.68163876
#  -0.47942554 -0.24740396  0.          0.24740396  0.47942554  0.68163876
#   0.84147098  0.94898462  0.99749499  0.98398595]
# [0.5, 0.479425538604203]
# [1.75, 0.9839859468739369]

# %%
x = np.arange(-2,2,0.25)
z = np.exp(x)
y = np.sin(x)
def point(x,y,i):
    return [x[i],y[i]]
print(y)
# Out:
# [-0.90929743 -0.98398595 -0.99749499 -0.94898462 -0.84147098 -0.68163876
#  -0.47942554 -0.24740396  0.          0.24740396  0.47942554  0.68163876
#   0.84147098  0.94898462  0.99749499  0.98398595]

# %%
x1 = 0
x2 = 1
y1 = point(x,y,x1)
y2 = point(x,y,x2)
z1 = point(x,z,x1)
z2 = point(x,z,x2)
tangent_y = line2pts9(x,y1,y2)
tangent_z = line2pts9(x,z1,z2)
plt.figure()
plt.plot(x,y,'b')
plt.plot(x,z,'b')
plt.plot(x,tangent_y,'g')
plt.plot(x,tangent_z,'g')
plt.plot([y1[0],y2[0],z1[0],z2[0]],[y1[1],y2[1],z1[1],z2[1]],'r.')
plt.grid()
plt.plot()
# Out:
# []
